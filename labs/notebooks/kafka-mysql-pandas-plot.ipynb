# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='mysql1',
    port=int('3306'),
    user='root',
    passwd='mypasswd',
    db='stock')

# %%
df = pd.read_sql_query("SELECT latest_update, latest_price FROM iextrading_filtered WHERE symbol='GOOG' ORDER BY latest_update", conn)

df.tail(10)
# Out:
#      latest_update  latest_price
# 112  1634287113508       1129.04
# 113  1634515916341       1166.96
# 114  1635933295984       1126.07
# 115  1636152462586       1167.38
# 116  1636431170314       1169.35
# 117  1636963941044       1157.75
# 118  1637387354277       1160.74
# 119  1638547060559       1123.16
# 120  1638666970127       1167.77
# 121  1639110111874       1122.66

# %%
# %matplotlib inline

df.index = df['latest_update']
plot = df['latest_price'].plot.line()

# %%
conn.close()
